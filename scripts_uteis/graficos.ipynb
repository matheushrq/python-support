# %% [markdown]
# <a href="https://colab.research.google.com/github/matheushrq/python-support/blob/main/graficos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1,2]
y = [2,3]
plt.plot(x, y)

plt.show()
